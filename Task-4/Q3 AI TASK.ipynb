# %%
import pandas as pd
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import metrics

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %%
import pandas as pd
data = pd.DataFrame({
    'sepal.length':iris.data[:,0],
    'sepal.width':iris.data[:,1],
    'petal.length':iris.data[:,2],
    'petal.width':iris.data[:,3],
    'variety':iris.target
})
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  variety
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
data.shape
# Out:
# (150, 5)

# %%
import warnings
warnings.filterwarnings("ignore")

sns.pairplot(data=data, hue='variety', palette = "Paired")

# %%
import warnings
warnings.filterwarnings("ignore")

sns.pairplot(data=data, hue='variety', palette = "Paired")

# %%
le = preprocessing.LabelEncoder()
le.fit(data.variety)

data['class_of_variety'] = le.transform(data.variety)

data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  variety  \
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0
#
#    class_of_variety
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
x = data.iloc[:,:-2]
y = data.iloc[:,5]

x.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class_of_variety, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)
model = SVC(gamma='scale')

model.fit(x_train, y_train)
# Out:
# SVC()

# %%
prediction = model.predict(x_test)
print("Accuracy in percentage:", round(metrics.accuracy_score(y_test, prediction),2)*100)
# Out:
# Accuracy in percentage: 96.0
